# %%
# from grlc import server
from grlc import utils

help(utils.build_swagger_spec)

spec = utils.build_swagger_spec('albertmeronyo', 'lodapi', None, 'localhost', None)
# print spec
# Out:
# INFO:rdflib:RDFLib Version: 4.2.1
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): api.github.com
# Help on function build_swagger_spec in module grlc.utils:
#
# build_swagger_spec(user, repo, sha, serverName, prov)
#     Build grlc specification for the given github user / repo in swagger format
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): api.github.com
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): api.github.com
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# INFO:grlc.utils:===================================================================
# INFO:grlc.utils:Processing SPARQL query: dbpedia_test.rq
# INFO:grlc.utils:===================================================================
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# select distinct ?type where {[] a ?type} LIMIT 20
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 150), (line:8, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# INFO:grlc.gquery:Decorator guessed endpoint: http://dbpedia.org/sparql
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# INFO:grlc.utils:===================================================================
# INFO:grlc.utils:Processing SPARQL query: ghostbusters_tracks.rq
# INFO:grlc.utils:===================================================================
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX mid: <http://example.org/midi/>
#
# SELECT ?track WHERE {
#     ?track a mid:Track .
# }
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 258), (line:9, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# INFO:grlc.gquery:Decorator guessed endpoint: https://raw.githubusercontent.com/albertmeronyo/lodapi/master/ghostbusters.ttl
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# INFO:grlc.utils:===================================================================
# INFO:grlc.utils:Processing SPARQL query: houseType_params.rq
# INFO:grlc.utils:===================================================================
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX cedar: <http://lod.cedar-project.nl:8888/cedar/resource/>
# PREFIX maritalstatus: <http://lod.cedar-project.nl/vocab/cedar-maritalstatus#>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-code: <http://purl.org/linked-data/sdmx/2009/code#>
# PREFIX cedarterms: <http://lod.cedar-project.nl/vocab/cedar#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX gg: <http://www.gemeentegeschiedenis.nl/amco/>
#
# SELECT (SUM(?pop) AS ?tot) FROM <urn:graph:cedar-mini:release> WHERE {
# 	?obs a qb:Observation.
# 	?obs sdmx-dimension:refArea ?_location_iri.
# 	?obs cedarterms:Kom ?_Kom_iri.
# 	?obs cedarterms:population ?pop.
# 	?slice a qb:Slice.
# 	?slice qb:observation ?obs.
# 	?slice sdmx-dimension:refPeriod ?_year_integer.
# 	?obs cedarterms:houseType ?_houseType_iri.
# 	?obs cedarterms:residenceStatus ?_residenceStatus_iri .
# 	FILTER (NOT EXISTS {?obs cedarterms:isTotal ?total })
# }
# # foo bar
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 832), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# WARNING:grlc.gquery:No endpoint specified, using default (http://virtuoso.clariah-sdh.eculture.labs.vu.nl/sparql)
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX cedar: <http://lod.cedar-project.nl:8888/cedar/resource/>
# PREFIX maritalstatus: <http://lod.cedar-project.nl/vocab/cedar-maritalstatus#>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-code: <http://purl.org/linked-data/sdmx/2009/code#>
# PREFIX cedarterms: <http://lod.cedar-project.nl/vocab/cedar#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX gg: <http://www.gemeentegeschiedenis.nl/amco/>
#
# SELECT (SUM(?pop) AS ?tot) FROM <urn:graph:cedar-mini:release> WHERE {
# 	?obs a qb:Observation.
# 	?obs sdmx-dimension:refArea ?_location_iri.
# 	?obs cedarterms:Kom ?_Kom_iri.
# 	?obs cedarterms:population ?pop.
# 	?slice a qb:Slice.
# 	?slice qb:observation ?obs.
# 	?slice sdmx-dimension:refPeriod ?_year_integer.
# 	?obs cedarterms:houseType ?_houseType_iri.
# 	?obs cedarterms:residenceStatus ?_residenceStatus_iri .
# 	FILTER (NOT EXISTS {?obs cedarterms:isTotal ?total })
# }
# # foo bar
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 832), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX cedar: <http://lod.cedar-project.nl:8888/cedar/resource/>
# PREFIX maritalstatus: <http://lod.cedar-project.nl/vocab/cedar-maritalstatus#>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-code: <http://purl.org/linked-data/sdmx/2009/code#>
# PREFIX cedarterms: <http://lod.cedar-project.nl/vocab/cedar#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX gg: <http://www.gemeentegeschiedenis.nl/amco/>
#
# SELECT (SUM(?pop) AS ?tot) FROM <urn:graph:cedar-mini:release> WHERE {
# 	?obs a qb:Observation.
# 	?obs sdmx-dimension:refArea ?_location_iri.
# 	?obs cedarterms:Kom ?_Kom_iri.
# 	?obs cedarterms:population ?pop.
# 	?slice a qb:Slice.
# 	?slice qb:observation ?obs.
# 	?slice sdmx-dimension:refPeriod ?_year_integer.
# 	?obs cedarterms:houseType ?_houseType_iri.
# 	?obs cedarterms:residenceStatus ?_residenceStatus_iri .
# 	FILTER (NOT EXISTS {?obs cedarterms:isTotal ?total })
# }
# # foo bar
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 832), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX cedar: <http://lod.cedar-project.nl:8888/cedar/resource/>
# PREFIX maritalstatus: <http://lod.cedar-project.nl/vocab/cedar-maritalstatus#>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-code: <http://purl.org/linked-data/sdmx/2009/code#>
# PREFIX cedarterms: <http://lod.cedar-project.nl/vocab/cedar#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX gg: <http://www.gemeentegeschiedenis.nl/amco/>
#
# SELECT (SUM(?pop) AS ?tot) FROM <urn:graph:cedar-mini:release> WHERE {
# 	?obs a qb:Observation.
# 	?obs sdmx-dimension:refArea ?_location_iri.
# 	?obs cedarterms:Kom ?_Kom_iri.
# 	?obs cedarterms:population ?pop.
# 	?slice a qb:Slice.
# 	?slice qb:observation ?obs.
# 	?slice sdmx-dimension:refPeriod ?_year_integer.
# 	?obs cedarterms:houseType ?_houseType_iri.
# 	?obs cedarterms:residenceStatus ?_residenceStatus_iri .
# 	FILTER (NOT EXISTS {?obs cedarterms:isTotal ?total })
# }
# # foo bar
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 832), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX cedar: <http://lod.cedar-project.nl:8888/cedar/resource/>
# PREFIX maritalstatus: <http://lod.cedar-project.nl/vocab/cedar-maritalstatus#>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-code: <http://purl.org/linked-data/sdmx/2009/code#>
# PREFIX cedarterms: <http://lod.cedar-project.nl/vocab/cedar#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX gg: <http://www.gemeentegeschiedenis.nl/amco/>
#
# SELECT (SUM(?pop) AS ?tot) FROM <urn:graph:cedar-mini:release> WHERE {
# 	?obs a qb:Observation.
# 	?obs sdmx-dimension:refArea ?_location_iri.
# 	?obs cedarterms:Kom ?_Kom_iri.
# 	?obs cedarterms:population ?pop.
# 	?slice a qb:Slice.
# 	?slice qb:observation ?obs.
# 	?slice sdmx-dimension:refPeriod ?_year_integer.
# 	?obs cedarterms:houseType ?_houseType_iri.
# 	?obs cedarterms:residenceStatus ?_residenceStatus_iri .
# 	FILTER (NOT EXISTS {?obs cedarterms:isTotal ?total })
# }
# # foo bar
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 832), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX cedar: <http://lod.cedar-project.nl:8888/cedar/resource/>
# PREFIX maritalstatus: <http://lod.cedar-project.nl/vocab/cedar-maritalstatus#>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-code: <http://purl.org/linked-data/sdmx/2009/code#>
# PREFIX cedarterms: <http://lod.cedar-project.nl/vocab/cedar#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX gg: <http://www.gemeentegeschiedenis.nl/amco/>
#
# SELECT (SUM(?pop) AS ?tot) FROM <urn:graph:cedar-mini:release> WHERE {
# 	?obs a qb:Observation.
# 	?obs sdmx-dimension:refArea ?_location_iri.
# 	?obs cedarterms:Kom ?_Kom_iri.
# 	?obs cedarterms:population ?pop.
# 	?slice a qb:Slice.
# 	?slice qb:observation ?obs.
# 	?slice sdmx-dimension:refPeriod ?_year_integer.
# 	?obs cedarterms:houseType ?_houseType_iri.
# 	?obs cedarterms:residenceStatus ?_residenceStatus_iri .
# 	FILTER (NOT EXISTS {?obs cedarterms:isTotal ?total })
# }
# # foo bar
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 832), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# INFO:grlc.utils:===================================================================
# INFO:grlc.utils:Processing TPF query: led_zeppelin_dbp.tpf
# INFO:grlc.utils:===================================================================
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# INFO:grlc.utils:===================================================================
# INFO:grlc.utils:Processing SPARQL query: rdfa_example.rq
# INFO:grlc.utils:===================================================================
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# SELECT * WHERE {
#     ?s ?p ?o .
# }
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 164), (line:7, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# INFO:grlc.gquery:Decorator guessed endpoint: http://iricelino.org/rdfa/sample-annotated-page.html
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# INFO:grlc.utils:===================================================================
# INFO:grlc.utils:Processing SPARQL query: statusbybirtyear_mult.rq
# INFO:grlc.utils:===================================================================
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX napp-dimension: <http://data.socialhistory.org/vocab/napp/dimension/>
# PREFIX clioprop: <http://data.socialhistory.org/resource/clio/property/>
# PREFIX clioind: <http://data.socialhistory.org/resource/clio/indicator/>
# PREFIX clioctr: <http://data.socialhistory.org/resource/clio/country/>
# PREFIX nappctr: <http://data.socialhistory.org/resource/napp/CNTRY/>
# PREFIX hisco: <http://data.socialhistory.org/vocab/hisco/>
# PREFIX hiscam: <http://data.socialhistory.org/vocab/hiscam/>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
#
# SELECT ?occhisco ?hisco ?hiscam ?gdppc ?year ?age
# FROM <http://data.socialhistory.org/resource/napp/dataset/sweden1890>
# FROM <http://data.socialhistory.org/resource/napp/dataset/canada1891>
# FROM <http://data.socialhistory.org/vocab/hisco/>
# FROM <http://data.socialhistory.org/resource/gdppc/assertion/5343176a06654392f04b0dcf163d1f1f0f65ffce/2016-01-21T16:30:48.081802>
# WHERE {
#     # get right clio data and year for right country
#     ?dataset clioprop:indicator clioind:GDPPC1990GKD .
#     ?dataset sdmx-dimension:refArea ?_clioctr .
#     ?dataset sdmx-measure:obsValue ?gdppc .
#     ?dataset sdmx-dimension:refPeriod ?year .
#     FILTER(xsd:int(str(?year)) < 1891) .
#
#     OPTIONAL{
#         # select variables of interest and filter out bad obs. from census
#         ?person napp-dimension:AGE ?age .
#         ?person napp-dimension:YEAR ?censusyear .
#         FILTER((?censusyear - ?age) = (xsd:int(str(?year))) && ?age != 999 && ?age > 12) .
#         ?person napp-dimension:OCCHISCO ?occhisco .
#         ?person napp-dimension:CNTRY ?_nappctr .
#         FILTER(?occhisco != 99999) .
#
#         # occupational mapping
#         ?occhisco (skos:closeMatch | skos:exactMatch) ?hisco .
#         ?hiscoentry hisco:hiscoCode ?hisco .
#         ?hiscoentry hiscam:hiscamValue ?hiscam .
#         ?hiscoentry qb:refArea hiscam:SE .
#     }
# }
# limit 100
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 869), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# WARNING:grlc.gquery:No endpoint specified, using default (http://virtuoso.clariah-sdh.eculture.labs.vu.nl/sparql)
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX napp-dimension: <http://data.socialhistory.org/vocab/napp/dimension/>
# PREFIX clioprop: <http://data.socialhistory.org/resource/clio/property/>
# PREFIX clioind: <http://data.socialhistory.org/resource/clio/indicator/>
# PREFIX clioctr: <http://data.socialhistory.org/resource/clio/country/>
# PREFIX nappctr: <http://data.socialhistory.org/resource/napp/CNTRY/>
# PREFIX hisco: <http://data.socialhistory.org/vocab/hisco/>
# PREFIX hiscam: <http://data.socialhistory.org/vocab/hiscam/>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
#
# SELECT ?occhisco ?hisco ?hiscam ?gdppc ?year ?age
# FROM <http://data.socialhistory.org/resource/napp/dataset/sweden1890>
# FROM <http://data.socialhistory.org/resource/napp/dataset/canada1891>
# FROM <http://data.socialhistory.org/vocab/hisco/>
# FROM <http://data.socialhistory.org/resource/gdppc/assertion/5343176a06654392f04b0dcf163d1f1f0f65ffce/2016-01-21T16:30:48.081802>
# WHERE {
#     # get right clio data and year for right country
#     ?dataset clioprop:indicator clioind:GDPPC1990GKD .
#     ?dataset sdmx-dimension:refArea ?_clioctr .
#     ?dataset sdmx-measure:obsValue ?gdppc .
#     ?dataset sdmx-dimension:refPeriod ?year .
#     FILTER(xsd:int(str(?year)) < 1891) .
#
#     OPTIONAL{
#         # select variables of interest and filter out bad obs. from census
#         ?person napp-dimension:AGE ?age .
#         ?person napp-dimension:YEAR ?censusyear .
#         FILTER((?censusyear - ?age) = (xsd:int(str(?year))) && ?age != 999 && ?age > 12) .
#         ?person napp-dimension:OCCHISCO ?occhisco .
#         ?person napp-dimension:CNTRY ?_nappctr .
#         FILTER(?occhisco != 99999) .
#
#         # occupational mapping
#         ?occhisco (skos:closeMatch | skos:exactMatch) ?hisco .
#         ?hiscoentry hisco:hiscoCode ?hisco .
#         ?hiscoentry hiscam:hiscamValue ?hiscam .
#         ?hiscoentry qb:refArea hiscam:SE .
#     }
# }
# limit 100
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 869), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# WARNING:grlc.gquery:Query metadata could not be parsed; check your YAML syntax
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX napp-dimension: <http://data.socialhistory.org/vocab/napp/dimension/>
# PREFIX clioprop: <http://data.socialhistory.org/resource/clio/property/>
# PREFIX clioind: <http://data.socialhistory.org/resource/clio/indicator/>
# PREFIX clioctr: <http://data.socialhistory.org/resource/clio/country/>
# PREFIX nappctr: <http://data.socialhistory.org/resource/napp/CNTRY/>
# PREFIX hisco: <http://data.socialhistory.org/vocab/hisco/>
# PREFIX hiscam: <http://data.socialhistory.org/vocab/hiscam/>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
#
# SELECT ?occhisco ?hisco ?hiscam ?gdppc ?year ?age
# FROM <http://data.socialhistory.org/resource/napp/dataset/sweden1890>
# FROM <http://data.socialhistory.org/resource/napp/dataset/canada1891>
# FROM <http://data.socialhistory.org/vocab/hisco/>
# FROM <http://data.socialhistory.org/resource/gdppc/assertion/5343176a06654392f04b0dcf163d1f1f0f65ffce/2016-01-21T16:30:48.081802>
# WHERE {
#     # get right clio data and year for right country
#     ?dataset clioprop:indicator clioind:GDPPC1990GKD .
#     ?dataset sdmx-dimension:refArea ?_clioctr .
#     ?dataset sdmx-measure:obsValue ?gdppc .
#     ?dataset sdmx-dimension:refPeriod ?year .
#     FILTER(xsd:int(str(?year)) < 1891) .
#
#     OPTIONAL{
#         # select variables of interest and filter out bad obs. from census
#         ?person napp-dimension:AGE ?age .
#         ?person napp-dimension:YEAR ?censusyear .
#         FILTER((?censusyear - ?age) = (xsd:int(str(?year))) && ?age != 999 && ?age > 12) .
#         ?person napp-dimension:OCCHISCO ?occhisco .
#         ?person napp-dimension:CNTRY ?_nappctr .
#         FILTER(?occhisco != 99999) .
#
#         # occupational mapping
#         ?occhisco (skos:closeMatch | skos:exactMatch) ?hisco .
#         ?hiscoentry hisco:hiscoCode ?hisco .
#         ?hiscoentry hiscam:hiscamValue ?hiscam .
#         ?hiscoentry qb:refArea hiscam:SE .
#     }
# }
# limit 100
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 869), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# INFO:grlc.utils:===================================================================
# INFO:grlc.utils:Processing SPARQL query: statusbybirtyear_mult_shouldwork.rq
# INFO:grlc.utils:===================================================================
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX napp-dimension: <http://data.socialhistory.org/vocab/napp/dimension/>
# PREFIX clioprop: <http://data.socialhistory.org/resource/clio/property/>
# PREFIX clioind: <http://data.socialhistory.org/resource/clio/indicator/>
# PREFIX clioctr: <http://data.socialhistory.org/resource/clio/country/>
# PREFIX nappctr: <http://data.socialhistory.org/resource/napp/CNTRY/>
# PREFIX hisco: <http://data.socialhistory.org/vocab/hisco/>
# PREFIX hiscam: <http://data.socialhistory.org/vocab/hiscam/>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
#
# SELECT ?occhisco ?hisco ?hiscam ?gdppc ?year ?age
# FROM <http://data.socialhistory.org/resource/napp/dataset/sweden1890>
# FROM <http://data.socialhistory.org/resource/napp/dataset/canada1891>
# FROM <http://data.socialhistory.org/vocab/hisco/>
# FROM <http://data.socialhistory.org/resource/gdppc/assertion/5343176a06654392f04b0dcf163d1f1f0f65ffce/2016-01-21T16:30:48.081802>
# WHERE {
#     # get right clio data and year for right country
#     ?dataset clioprop:indicator clioind:GDPPC1990GKD .
#     ?dataset sdmx-dimension:refArea ?_clioctr .
#     ?dataset sdmx-measure:obsValue ?gdppc .
#     ?dataset sdmx-dimension:refPeriod ?year .
#     FILTER(xsd:int(str(?year)) < 1891) .
#
#     OPTIONAL{
#         # select variables of interest and filter out bad obs. from census
#         ?person napp-dimension:AGE ?age .
#         ?person napp-dimension:YEAR ?censusyear .
#         FILTER((?censusyear - ?age) = (xsd:int(str(?year))) && ?age != 999 && ?age > 12) .
#         ?person napp-dimension:OCCHISCO ?occhisco .
#         ?person napp-dimension:CNTRY ?_nappctr .
#         FILTER(?occhisco != 99999) .
#
#         # occupational mapping
#         ?occhisco (skos:closeMatch | skos:exactMatch) ?hisco .
#         ?hiscoentry hisco:hiscoCode ?hisco .
#         ?hiscoentry hiscam:hiscamValue ?hiscam .
#         ?hiscoentry qb:refArea hiscam:SE .
#     }
# }
# limit 100
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 878), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# INFO:requests.packages.urllib3.connectionpool:Starting new HTTPS connection (1): raw.githubusercontent.com
# WARNING:grlc.gquery:No endpoint specified, using default (http://virtuoso.clariah-sdh.eculture.labs.vu.nl/sparql)
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX napp-dimension: <http://data.socialhistory.org/vocab/napp/dimension/>
# PREFIX clioprop: <http://data.socialhistory.org/resource/clio/property/>
# PREFIX clioind: <http://data.socialhistory.org/resource/clio/indicator/>
# PREFIX clioctr: <http://data.socialhistory.org/resource/clio/country/>
# PREFIX nappctr: <http://data.socialhistory.org/resource/napp/CNTRY/>
# PREFIX hisco: <http://data.socialhistory.org/vocab/hisco/>
# PREFIX hiscam: <http://data.socialhistory.org/vocab/hiscam/>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
#
# SELECT ?occhisco ?hisco ?hiscam ?gdppc ?year ?age
# FROM <http://data.socialhistory.org/resource/napp/dataset/sweden1890>
# FROM <http://data.socialhistory.org/resource/napp/dataset/canada1891>
# FROM <http://data.socialhistory.org/vocab/hisco/>
# FROM <http://data.socialhistory.org/resource/gdppc/assertion/5343176a06654392f04b0dcf163d1f1f0f65ffce/2016-01-21T16:30:48.081802>
# WHERE {
#     # get right clio data and year for right country
#     ?dataset clioprop:indicator clioind:GDPPC1990GKD .
#     ?dataset sdmx-dimension:refArea ?_clioctr .
#     ?dataset sdmx-measure:obsValue ?gdppc .
#     ?dataset sdmx-dimension:refPeriod ?year .
#     FILTER(xsd:int(str(?year)) < 1891) .
#
#     OPTIONAL{
#         # select variables of interest and filter out bad obs. from census
#         ?person napp-dimension:AGE ?age .
#         ?person napp-dimension:YEAR ?censusyear .
#         FILTER((?censusyear - ?age) = (xsd:int(str(?year))) && ?age != 999 && ?age > 12) .
#         ?person napp-dimension:OCCHISCO ?occhisco .
#         ?person napp-dimension:CNTRY ?_nappctr .
#         FILTER(?occhisco != 99999) .
#
#         # occupational mapping
#         ?occhisco (skos:closeMatch | skos:exactMatch) ?hisco .
#         ?hiscoentry hisco:hiscoCode ?hisco .
#         ?hiscoentry hiscam:hiscamValue ?hiscam .
#         ?hiscoentry qb:refArea hiscam:SE .
#     }
# }
# limit 100
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 878), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
# INFO:grlc.gquery:Trying to parse udpate query
# ERROR:grlc.gquery:Could not parse UPDATE query
# ERROR:grlc.gquery:
# PREFIX napp-dimension: <http://data.socialhistory.org/vocab/napp/dimension/>
# PREFIX clioprop: <http://data.socialhistory.org/resource/clio/property/>
# PREFIX clioind: <http://data.socialhistory.org/resource/clio/indicator/>
# PREFIX clioctr: <http://data.socialhistory.org/resource/clio/country/>
# PREFIX nappctr: <http://data.socialhistory.org/resource/napp/CNTRY/>
# PREFIX hisco: <http://data.socialhistory.org/vocab/hisco/>
# PREFIX hiscam: <http://data.socialhistory.org/vocab/hiscam/>
# PREFIX sdmx-dimension: <http://purl.org/linked-data/sdmx/2009/dimension#>
# PREFIX sdmx-measure: <http://purl.org/linked-data/sdmx/2009/measure#>
# PREFIX qb: <http://purl.org/linked-data/cube#>
# PREFIX skos: <http://www.w3.org/2004/02/skos/core#>
#
# SELECT ?occhisco ?hisco ?hiscam ?gdppc ?year ?age
# FROM <http://data.socialhistory.org/resource/napp/dataset/sweden1890>
# FROM <http://data.socialhistory.org/resource/napp/dataset/canada1891>
# FROM <http://data.socialhistory.org/vocab/hisco/>
# FROM <http://data.socialhistory.org/resource/gdppc/assertion/5343176a06654392f04b0dcf163d1f1f0f65ffce/2016-01-21T16:30:48.081802>
# WHERE {
#     # get right clio data and year for right country
#     ?dataset clioprop:indicator clioind:GDPPC1990GKD .
#     ?dataset sdmx-dimension:refArea ?_clioctr .
#     ?dataset sdmx-measure:obsValue ?gdppc .
#     ?dataset sdmx-dimension:refPeriod ?year .
#     FILTER(xsd:int(str(?year)) < 1891) .
#
#     OPTIONAL{
#         # select variables of interest and filter out bad obs. from census
#         ?person napp-dimension:AGE ?age .
#         ?person napp-dimension:YEAR ?censusyear .
#         FILTER((?censusyear - ?age) = (xsd:int(str(?year))) && ?age != 999 && ?age > 12) .
#         ?person napp-dimension:OCCHISCO ?occhisco .
#         ?person napp-dimension:CNTRY ?_nappctr .
#         FILTER(?occhisco != 99999) .
#
#         # occupational mapping
#         ?occhisco (skos:closeMatch | skos:exactMatch) ?hisco .
#         ?hiscoentry hisco:hiscoCode ?hisco .
#         ?hiscoentry hiscam:hiscamValue ?hiscam .
#         ?hiscoentry qb:refArea hiscam:SE .
#     }
# }
# limit 100
#
# Traceback (most recent call last):
#   File "/usr/local/lib/python2.7/dist-packages/grlc/gquery.py", line 213, in get_metadata
#     parsed_query = UpdateUnit.parseString(rq, parseAll=True)
#   File "/usr/local/lib/python2.7/dist-packages/pyparsing.py", line 1129, in parseString
#     raise exc
# ParseException: Expected end of text (at char 878), (line:20, col:1)
# ERROR:grlc.gquery:None
# INFO:grlc.gquery:Finished parsing query of type SelectQuery
